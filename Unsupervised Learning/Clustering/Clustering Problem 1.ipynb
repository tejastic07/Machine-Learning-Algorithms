# %% [markdown]
# # Step 1 :- Import data & Library

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
Jewellary = pd.read_csv(r'C:\Users\admin\Desktop\Machine Learning\Unsupervised\Clustering\Jewellary.csv')

# %%
Jewellary.shape
# Out:
# (505, 4)

# %%
Jewellary
# Out:
#      Age  Income  SpendingScore       savings
# 0     58   77769       0.791329   6559.829923
# 1     59   81799       0.791082   5417.661426
# 2     62   74751       0.702657   9258.992965
# 3     59   74373       0.765680   7346.334504
# 4     87   17760       0.348778  16869.507130
# ..   ...     ...            ...           ...
# 500   28  101206       0.387441  14936.775390
# 501   93   19934       0.203140  17969.693770
# 502   90   35297       0.355149  16091.401950
# 503   91   20681       0.354679  18401.088440
# 504   89   30267       0.289310  14386.351880
#
# [505 rows x 4 columns]

# %% [markdown]
# # Step 2 :-  Take specific Variable for Analysis

# %%
data = Jewellary.iloc[:, 3:5].values
data[0:2]
# Out:
# array([[6559.829923],
#        [5417.661426]])

# %%
data
# Out:
# array([[ 6559.829923 ],
#        [ 5417.661426 ],
#        [ 9258.992965 ],
#        [ 7346.334504 ],
#        [16869.50713  ],
#        [ 3535.514352 ],
#        [ 6878.884249 ],
#        [18086.28716  ],
#        [14783.37909  ],
#        [17879.55891  ],
#        [16009.23776  ],
#        [16398.40133  ],
#        [13621.63973  ],
#        [13407.08139  ],
#        [ 8022.208541 ],
#        [13709.67027  ],
#        [ 7780.589914 ],
#        [16180.68808  ],
#        [17866.8336   ],
#        [14264.47385  ],
#        [14324.55598  ],
#        [13809.73409  ],
#        [ 5168.225475 ],
#        [15407.64676  ],
#        [16215.39908  ],
#        [ 5706.149573 ],
#        [ 4128.044796 ],
#        [ 8376.749478 ],
#        [17258.57497  ],
#        [ 7467.036702 ],
#        [ 6932.487932 ],
#        [ 7151.650866 ],
#        [17472.47069  ],
#        [ 7762.255067 ],
#        [14911.8684   ],
#        [ 5103.60923  ],
#        [16816.9119   ],
#        [ 7283.504773 ],
# ...

# %% [markdown]
# # Step 3 :-  Dendogram

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(20, 4))
plt.title("Jewellary Dendograms")
dend = shc.dendrogram(shc.linkage(data, method='ward',metric='euclidean')) 
#ward = minimum of variance  
#single = Minimum of distance

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2,affinity='euclidean', linkage='ward') # ward = minimum

# %%
Jewellary['Group']=cluster.fit_predict(data)
Jewellary.head()
# Out:
#    Age  Income  SpendingScore       savings  Group
# 0   58   77769       0.791329   6559.829923      1
# 1   59   81799       0.791082   5417.661426      1
# 2   62   74751       0.702657   9258.992965      1
# 3   59   74373       0.765680   7346.334504      1
# 4   87   17760       0.348778  16869.507130      0

# %% [markdown]
# * plt.figure(figsize=(12, 4))
# * plt.scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')

# %%
import seaborn as sns 
sns.scatterplot(Jewellary['Income'],Jewellary['SpendingScore'],Jewellary['savings'],
                hue='Group',
                data=customer_data,
                palette="turbo")
# Out:
# <AxesSubplot:xlabel='Income', ylabel='SpendingScore'>

# %%
Jewellary
# Out:
#      Age  Income  SpendingScore       savings  Group
# 0     58   77769       0.791329   6559.829923      1
# 1     59   81799       0.791082   5417.661426      1
# 2     62   74751       0.702657   9258.992965      1
# 3     59   74373       0.765680   7346.334504      1
# 4     87   17760       0.348778  16869.507130      0
# ..   ...     ...            ...           ...    ...
# 500   28  101206       0.387441  14936.775390      0
# 501   93   19934       0.203140  17969.693770      0
# 502   90   35297       0.355149  16091.401950      0
# 503   91   20681       0.354679  18401.088440      0
# 504   89   30267       0.289310  14386.351880      0
#
# [505 rows x 5 columns]

# %%
Jewellary.Group.value_counts(ascending=False)
# Out:
# 0    298
# 1    207
# Name: Group, dtype: int64

# %%
np.sum(Jewellary.Group.value_counts(ascending=False).values.tolist())
# Out:
# 505

# %% [markdown]
# # Business Submission

# %%
Final_Output = Jewellary.iloc[:,[0,4]]
Final_Output
# Out:
#      Age  Group
# 0     58      1
# 1     59      1
# 2     62      1
# 3     59      1
# 4     87      0
# ..   ...    ...
# 500   28      0
# 501   93      0
# 502   90      0
# 503   91      0
# 504   89      0
#
# [505 rows x 2 columns]

# %%
import os
os.chdir(r"C:\Users\admin\Desktop\Machine Learning\Unsupervised\Clustering")

# %%
Final_Output.to_csv("Shopping_data_output.csv",index=False)

# %% [markdown]
# # FINISHED
